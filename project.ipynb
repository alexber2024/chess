# %% [markdown]
# # Creating a Chess Engine based on Deep Learning model
#
# Github repo: https://github.com/alexber2024/chess
#
# ### 1. Project Topic
#
# The goal of this project was to build a chess engine based purely on Deep Learning, without relying at all on search algorithms (like Minimax or Monte Carlo Tree Search). This is a challenging and non-trivial task in the world of chess programming, since all known chess engines, including the top ones like AlphaZero or Stockfish, are heavily dependent on search, even if they use Deep Learning for position evaluations. By "search" I mean exploring huge number of variations of move sequences, sometimes with depth of 20, 30 or more. Instead of using search, my chess engine plays by choosing the best move according to numerical evaluation of all legal moves in a position, without considering next moves.
#
# The central part of my chess engine is the Deep Learning model and it is the main focus of this Jupyter Notebook. I trained the model on large dataset of chess positions, and it learned to predict an evaluation of a position. This is a regression task, since the output is a continuous value. In addition, my model also needed to recognize checkmate positions and evaluate them accordingly. The checkmates evaluation was a challenging part and I addressed it separately. Another challenge was to ensure the model was not only performing well on a validation set, but could actually play decent chess. These are not the same thing, and I had to solve this with unique approach to data augmentation and a few other optimizations.
#
# Chess is a complex game with many rules, and if you've ever played a game or two, you know that it is not easy to learn the rules, and much harder to learn how to actually win. Luckily, I didn't need to implement the chess rules for my engine. I used the python-chess library for that, which handled all rules enforcement, legal moves generation, board representation and etc. So my model didn't have to learn the rules of chess, but to learn how to win the game.
#
# In the following sections I will describe the data I used, the EDA, the architecture of my model, and will discuss the results and conclusions.

# %% [markdown]
# ### 2. Data
#
# My initial data comes from Kaggle: https://www.kaggle.com/datasets/ronakbadhe/chess-evaluations. It includes 2 files with evaluations data
#
# * random_evals.csv
# * tactic_evals.csv
#
# All these datasets have similar structure with two columns: the position and evaluation. The position is represented in a FEN notaion, a short format to describe the position of all pieces on a chess board. The evaluation can be of two types: a score, or moves-to-mate.
#
# Those evaluations were generated by Stockfish chess engine, the strongest chess engine in the world. The 11th version of Stockfish, which was used for those evaluaions, was released in 2020. It was using a hand-crafted algorithm for calculating evaluations. A year later the evaluation algorithm was replaced by a deep learning approach (the NNUE architecture), but for my purposes the 11th version is more than enough - it has an ELO rating of 3400+, which is far beyond Grandmasters' levels.
#
# The total amount of evaluation in those files are 3.6 millions. I will use the random_eval.csv evaluations for my initial model, as it seemed to give the best results. Here are the dataset details:

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('data/random_evals.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000273 entries, 0 to 1000272
# Data columns (total 2 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   FEN         1000273 non-null  object
#  1   Evaluation  1000273 non-null  object
# dtypes: object(2)
# memory usage: 15.3+ MB

# %% [markdown]
# And here are some samples of evaluations:

# %%
pd.set_option('display.max_colwidth', None)

df.head(10)
# Out:
#                                                               FEN Evaluation
# 0   rnbqkb1r/pppppppp/B4n2/8/4P3/8/PPPP1PPP/RNBQK1NR b KQkq - 2 2       -459
# 1  rnbqkb1r/pppppppp/5n2/1B6/4P3/8/PPPP1PPP/RNBQK1NR b KQkq - 2 2       -125
# 2    rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2       +198
# 3   rnbqkb1r/pppppppp/5n2/8/4P3/7N/PPPP1PPP/RNBQKB1R b KQkq - 2 2       -155
# 4    rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2       +209
# 5  rnbqkb1r/pppppppp/5n2/8/2B1P3/8/PPPP1PPP/RNBQK1NR b KQkq - 2 2       -101
# 6  rnbqkb1r/pppppppp/5n2/8/4P3/5N2/PPPP1PPP/RNBQKB1R b KQkq - 2 2       -105
# 7    rnbqkb1r/pppppppp/5n2/8/4P3/8/PPPPNPPP/RNBQKB1R b KQkq - 2 2       -136
# 8   rnbqkb1r/pppppppp/5n2/7Q/4P3/8/PPPP1PPP/RNB1KBNR b KQkq - 2 2      -1262
# 9    rnbqkb1r/pppppppp/5n2/8/4P3/8/PPPPBPPP/RNBQK1NR b KQkq - 2 2       -117

# %% [markdown]
# The FEN notation is using letters and numbers to represend board configuration. The "/" symbol divides the ranks of the board (horizontal rows). The letters represent piece type (r - Rook, n - Knight, b - Bishop, k - King, p - Pawn, q - Queen). Uppercase letter are for white pices and lowercase are for black. Numbers represents the count of empty consequtive squares. After the 8 ranks there is a 'w' or 'b' letter indicating the side to move in a position and final KQkq letters indicating the avalable castling options.
#
# The evaluation can be of two types. One is an integer number representing the numerical score of a position. Negative evaluation means the position is in favour of Black, positive - in favour of White. The value is based on centi-pawn measure, which is approximately 100 units for a Pawn, 300 for a Knight or a Bishop, 5 for a Rook and 9 for a Queen. The score can also be affected by other factors, like threats, checks, defence, and many other tactical or strategical factors. As an example, evaluation of -100 indicates Black has a 1 pawn advantage, or equivalent tactical/strategic opportunities.
#
# Another type of the evaluation is "moves-to-mate". It takes a form of '#' sign and a number, for example '#+2' means white can checkmate in two moves, '#-1' means black can checkmate in 1 move. '#+0' means white won by a check mate '#-0' means black won by a checkmate.

# %% [markdown]
# ### 3. Exploratory Data Analysis (EDA)
#
# In this section I will explore and analyse the data. I will start by a simple example for a randomly selected evaluation record:
#
#
# **4r1k1/1p1r2bp/pq4p1/8/4pPN1/1P1pQ2R/P1P3PP/4R1K1 w - - 2 30,+794**
#
#
# I will use chess.com website to generate board state images and visualize FEN notations. The above FEN represents the following position:
#
# ![](https://raw.githubusercontent.com/alexber2024/chess/refs/heads/main/images/board1.png)
#
# The evaluation is +794 in favour of White. This totally makes sense as White has a really strong move (I'll leave it for you to discover)
#
# Another example is for moves-to-mate score:
#
# **2r2rk1/pp3p1p/2p1p1P1/5q2/6Q1/2P3R1/5PP1/4R1K1 w - - 1 23,#+2**
#
# ![](https://raw.githubusercontent.com/alexber2024/chess/refs/heads/main/images/board2.png)
#
# It's White turn to move, and it is mate in two moves.
#
# Now that it's clear how FEN notation works, and what the evaluations mean, I will perform some general visualizations, which will help to understand the contents of the dataset. I'll begin with some statistics:

# %%
# max, min and mean scores
data = df.to_numpy()
data_scores = data[~np.char.startswith(data[:, 1].astype(str), '#')]
data_mtm = data[np.char.startswith(data[:, 1].astype(str), '#')]

print(f'Max score: {np.max(data_scores[:, 1].astype(int))}')
print(f'Min score: {np.min(data_scores[:, 1].astype(int))}')
print(f'Mean score: {np.mean(data_scores[:, 1].astype(int))}')

print()

mtm_values = np.array([int(x[1:]) for x in data_mtm[:, 1]])
print(f'Max moves to mate: {np.max(mtm_values)}')
print(f'Min moves to mate: {np.min(mtm_values)}')
print(f'Mean moves to mate: {np.mean(mtm_values)}')
# Out:
# Max score: 14489
# Min score: -15265
# Mean score: 10.2501035477416
#
# Max moves to mate: 43
# Min moves to mate: -54
# Mean moves to mate: 0.381273994028153

# %% [markdown]
# Now that I know the range for both types of evaluation, I will visualize their distributions.

# %%
import matplotlib.pyplot as plt

plt.hist(data_scores[:, 1].astype(int), bins=50)
plt.title('Histogram of scores')
plt.xlabel('Score')
plt.ylabel('Frequency (scale)')
plt.grid(True)
plt.show()

# %% [markdown]
# Most of the evaluations are in the range of -2000 to +2000, with a huge spike around 0. This makes sense, as when the game begins the scores of the initial positions are around zero. Then in the middle of the game the score can start to deviate. When the score reaches the value of +-500 or +-1000, it indicates a big advantage for one of the sides. The symmetry of the data suggests a good variety of positions, with both Black and White advantages. To make it clearer, I'll show this histogram in log scale:

# %%
plt.hist(data_scores[:, 1].astype(int), bins=50, log=True)
plt.title('Log Histogram of Scores')
plt.xlabel('Score')
plt.ylabel('Frequency (log scale)')
plt.grid(True)
plt.show()

# %% [markdown]
# The log scale shows that there is a big amount of scores in a wider range, between -10000 and 10000. This can indicate a presence of end-game positions, where one side has a big advantage. The symmetry is preserved on a log scale.
#
# I will also check the histogram of moves-to-mate evaluations:

# %%
plt.hist(mtm_values, bins=98, range=(-54, 43), log=True)
plt.title('Histogram of Moves to Mate')
plt.xlabel('Moves to Mate')
plt.ylabel('Frequency (scale)')
plt.grid(True)
plt.show()

# %% [markdown]
# The above histogram shows a wide variety of moves-to-mate positions. But it doesn't have much checkmate positions (#+0 and #-0): less than 300 positions, which is not much for training. For the checkmates model I will the second dataset, tacic_evals.csv. And here is the distribution (more than 150k checkmate positions):

# %%
df = pd.read_csv('data/tactic_evals.csv')
df.info()
data_mtm = df.to_numpy()
data_mtm = data_mtm[np.char.startswith(data_mtm[:, 1].astype(str), '#')]

mtm_values = np.array([int(x[1:]) for x in data_mtm[:, 1]])

plt.hist(mtm_values, bins=41, range=(-20, 20))
plt.title('Histogram of Moves to Mate')
plt.xlabel('Moves to Mate')
plt.ylabel('Frequency (scale)')
plt.grid(True)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2628219 entries, 0 to 2628218
# Data columns (total 3 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   FEN         object
#  1   Evaluation  object
#  2   Move        object
# dtypes: object(3)
# memory usage: 60.2+ MB

# %% [markdown]
# In addition to those visualizations I checked a few randomly selected positions and evaluated them on chess.com website. The scores I got were very close to ones in the dataset, so I assume I can trust the data.

# %% [markdown]
# ### 4. Model and Architecture
#
# #### 4.1 Input encoding
#
# Before building the model I had to decide about the input encoding, which would be suitable for a neural network. Obviously I couldn't use the FEN string as is, and I decided to transform the FENs into 8x8x17 tensors. Each 3D tensor has 17 feature planes in a size of a chessboard (8x8) The first 12 of those planes represent apresence of a piece type and color in specific position (1 where a piece occupies the corresponding square). 5 last planes are for game state info like side-to-move and castling options. Below is the code for transforming a python-chess board object into a tensor:

# %%
import chess
import numpy as np

# Function to convert a chess board to a tensor representation
# The tensor shape is (8, 8, 17) where:
# - 8x8 for the board squares
# - 17 channels for different pieces and game state information
#   (12 piece types + 1 side to move + 4 castling rights)
def board_to_tensor(board):
    tensor = np.zeros((8, 8, 17), dtype=np.int8)

    for square in chess.SQUARES:
        piece = board.piece_at(square)
        if piece:
            piece_type = piece.piece_type  # 1 (pawn) to 6 (king)
            color = int(piece.color)       # 0 for white, 1 for black
            idx = piece_type - 1 + (6 * color)

            row = 7 - (square // 8)  # Flip rank: 0 (a1..h1) becomes 7
            col = square % 8         # File stays the same
            tensor[row, col, idx] = 1

    # Add side to move in channel 12
    tensor[:, :, 12] = 1 if board.turn == chess.WHITE else 0
    # Add castling rights in channels 13-16
    tensor[:, :, 13] = int(board.has_kingside_castling_rights(chess.WHITE))
    tensor[:, :, 14] = int(board.has_queenside_castling_rights(chess.WHITE))
    tensor[:, :, 15] = int(board.has_kingside_castling_rights(chess.BLACK))
    tensor[:, :, 16] = int(board.has_queenside_castling_rights(chess.BLACK))

    return tensor

# %% [markdown]
# As an example I will transform the following position:
#
# **4r1k1/1p1r2bp/pq4p1/8/4pPN1/1P1pQ2R/P1P3PP/4R1K1 w - - 2 30,+794**
#
# ![](https://raw.githubusercontent.com/alexber2024/chess/refs/heads/main/images/board1.png)
#
# Below is the code to create the tensor, and its vizualization as 17 grids with white squares for 1 and black squares for 0:

# %%
tensor = board_to_tensor(chess.Board("4r1k1/1p1r2bp/pq4p1/8/4pPN1/1P1pQ2R/P1P3PP/4R1K1 w - - 2 30"))

pieces = [
    'Pawn (Black)', 'Knight (Black)', 'Bishop (Black)', 'Rook (Black)',
    'Queen (Black)', 'King (Black)', 'Pawn (White)', 'Knight (White)',
    'Bishop (White)', 'Rook (White)', 'Queen (White)', 'King (White)',
    'Side to Move', 'White Castling K',
    'White Castling Q', 'Black Castling K', 'Black Castling Q'
]
for i in range(17):
    plt.subplot(4, 5, i + 1)
    plt.imshow(tensor[:, :, i], cmap='gray', vmin=0, vmax=1)
    plt.title(f'{pieces[i]}', fontsize=8)
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# The reason I've chosen this encoding is to have a clear separation between piece types, and to allow the model to learn the relationships between different piece-square-color variations. Another reason is related to the fact that a chess board with pieces on it resembles an image. The only difference is that instead of pixels it has 8x8 grid of squares, and instead of 3 color channels it has 17 channels of pieces information and other data. This representation suggests that image-recognition approach can be applied for chess modeling in order to recognize patterns in chess positions. The central idea in image-recognition models is the usage of Convolutional Neural Networks. And I decided it would make sense to use CNN for chess data as well.
#
# (*The 17-channels encoding is common for chess models, but not the only one. I explored a few others, but they resulted in a weaker performance.*)
#
# #### 4.2 Processing the data
#
# The next step was to process the data and convert it to tensor structure. I used 500k samples from the dataset:

# %%
import numpy as np
import pandas as pd

# Load the CSV file
df = pd.read_csv('data/random_evals.csv')
# Convert the DataFrame to a numpy array
data = df.to_numpy()
# remove lines with evaluation starting with '#'
data = data[~np.char.startswith(data[:, 1].astype(str), '#')]

data = data[np.random.choice(data.shape[0], 500000, replace=False)]

X = data[:, 0]  # Features (FEN strings)
y = data[:, 1].astype(float)  # Labels (evaluations)

# Convert FEN strings to tensors
X_tensors = np.array([board_to_tensor(chess.Board(fen)) for fen in X])
# Reshape the tensors to match the input shape of the model
X_tensors = X_tensors.reshape(X_tensors.shape[0], 8, 8, 17)

# I will also split the data into training and validation sets
split_index = int(0.8 * len(X_tensors))
X_train = X_tensors[:split_index]
y_train = y[:split_index]
X_val = X_tensors[split_index:]
y_val = y[split_index:]

print(f'X shape: {X_tensors.shape}')
print(f'y shape: {y.shape}')
# Out:
# X shape: (500000, 8, 8, 17)
# y shape: (500000,)

# %% [markdown]
# I only included evaluations of score-type in the above dataset. The move-to-mate evaluations are not suitable for a regression model, and I ignored them for now.
#
# #### 4.3 Model for score evaluations
#
# Now I can speak about the model architecture. I tried many different approaches, regularizations and hyperparameter tuning, and had a few interesting findings:
# * The Dropout(), BatchNormalization() and MaxPooling2D() layers didn't work well
# * The batch size didn't have much effect.
# * Flattening the input and using simple Dense() layers resulted in almost the same performance as CNN model.
# * The 3x3 kernel size for CNN filter worked best.
#
# In general, I saw the model learns well and minimizes the loss on the validation set. I will discuss those findings and the comparison of different architecture and hyperparameter tuning approaches in the Result section. But, as I already mentioned, the performance of my model on a validation set is only one part of the work, and the real metrics for the model is about how it plays (and wins) chess.
#
# The model I came up with has 3 CNN layers of 128, 64 and 32 filters, with 3x3 kernel size, and 1 Dense layer. All activations are ReLu. The output layer has a single unit with softmax activation function, which is suitable for continuous values.
#
# Below is the implementation and training of the model:

# %%
from tensorflow.keras import layers, models
import tensorflow as tf
from tensorflow.keras.optimizers import Adam


model = models.Sequential([
    layers.Input(shape=(8, 8, 17)),
    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(1, activation='linear')

])

model.compile(optimizer=Adam(learning_rate=0.001),
              loss='mean_squared_error',
              metrics=[tf.keras.metrics.MeanAbsoluteError()])

# Train the model
history = model.fit(X_train, y_train,
                    validation_data=(X_val, y_val),
                    epochs=10,
                    batch_size=32)

# Save the model
model.save('models/model_scores.keras')
# Out:
# Epoch 1/10
# 12500/12500 ━━━━━━━━━━━━━━━━━━━━ 125s 10ms/step - loss: 748194.8125 - mean_absolute_error: 487.2530 - val_loss: 509849.3125 - val_mean_absolute_error: 425.7226
# Epoch 2/10
# 12500/12500 ━━━━━━━━━━━━━━━━━━━━ 130s 10ms/step - loss: 465887.5625 - mean_absolute_error: 385.9951 - val_loss: 430999.6875 - val_mean_absolute_error: 372.0511
# Epoch 3/10
# 12500/12500 ━━━━━━━━━━━━━━━━━━━━ 127s 10ms/step - loss: 395609.1875 - mean_absolute_error: 349.6151 - val_loss: 396967.2812 - val_mean_absolute_error: 349.2591
# Epoch 4/10
# 12500/12500 ━━━━━━━━━━━━━━━━━━━━ 126s 10ms/step - loss: 348615.0938 - mean_absolute_error: 328.4920 - val_loss: 355688.9688 - val_mean_absolute_error: 319.5683
# Epoch 5/10
# 12500/12500 ━━━━━━━━━━━━━━━━━━━━ 124s 10ms/step - loss: 320363.3125 - mean_absolute_error: 313.9937 - val_loss: 341264.6562 - val_mean_absolute_error: 312.4158
# Epoch 6/10
# 12500/12500 ━━━━━━━━━━━━━━━━━━━━ 125s 10ms/step - loss: 294347.2500 - mean_absolute_error: 300.8802 - val_loss: 361560.0938 - val_mean_absolute_error: 336.9094
# Epoch 7/10
# 12500/12500 ━━━━━━━━━━━━━━━━━━━━ 130s 10ms/step - loss: 272067.2500 - mean_absolute_error: 291.5376 - val_loss: 314306.9375 - val_mean_absolute_error: 288.2073
# Epoch 8/10
# 12500/12500 ━━━━━━━━━━━━━━━━━━━━ 126s 10ms/step - loss: 258058.0469 - mean_absolute_error: 283.3284 - val_loss: 316882.5312 - val_mean_absolute_error: 286.4114
# Epoch 9/10
# 12500/12500 ━━━━━━━━━━━━━━━━━━━━ 128s 10ms/step - loss: 239750.8125 - mean_absolute_error: 275.0867 - val_loss: 309824.9062 - val_mean_absolute_error: 283.0462
# Epoch 10/10
# 12500/12500 ━━━━━━━━━━━━━━━━━━━━ 129s 10ms/step - loss: 229982.1250 - mean_absolute_error: 270.4693 - val_loss: 303483.9688 - val_mean_absolute_error: 277.6435

# %% [markdown]
# The model reached a mean absolute error of 277.6 This seems quite good, given the wide range of evaluations. I will also plot a graph of sorted evaluations from validation set overlayed by predicted evaluations. This will give an idea of how well the model predicts evaluations:

# %%
def plot_predicted_vs_original(X_val, y_val, model):
# Get predictions
    predictions = model.predict(X_val)
    # Sort by original evaluation scores
    sorted_indices = np.argsort(y_val)
    sorted_original_scores = y_val[sorted_indices]
    sorted_predictions = predictions[sorted_indices]

    plt.figure(figsize=(12, 6))
    plt.plot(sorted_original_scores, label='Original Scores', color='blue')
    # Apply moving average to smooth the predicted scores. Just to reduce noise
    window_size = 20
    smoothed_predictions = np.convolve(sorted_predictions.flatten(), np.ones(window_size)/window_size, mode='same')
    plt.plot(smoothed_predictions, label='Predicted Scores (Moving Avg)', color='orange', alpha=0.7)
    plt.title('Original vs Predicted Evaluation Scores (with Moving Average)')
    plt.xlabel('Sample Index (sorted by original scores)')
    plt.ylabel('Score')
    plt.legend()
    plt.grid(True)
    plt.show()

plot_predicted_vs_original(X_val, y_val, model)
# Out:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step

# %% [markdown]
# Before moving forward, I will borrow an image from the Results section, to show the performance of my model in my chess engine:
#
# ![](https://raw.githubusercontent.com/alexber2024/chess/refs/heads/main/images/board3.png)

# %% [markdown]
# The above image is the position of a game after 35 moves, where my chess engine based on the CNN model (White pieces) plays against a very weak randomly-moving engine. It is clear that my model learned how to capture pieces, but it didn't learn how to win. (There is no checkmate at that position)
#
# The reason for that is because I didn't train the model on the moves-to-mate evaluations, so the model didn't learn to evaluate checkmates moves.
#
# To solve that I had two options: creating a separate (classification) model and train it on moves-to-mate evaluations, or converting the moves-to-mate evaluations to a value-based score and mix it (or combine) with the initial model. I tried both options, and the second worked better. Now I will describe it in more details.
#
# #### 4.4 Model for moves-to-mates evaluations
#
# I had to create a dataset for the new model, with checkmate positions, and I used the 'tactic_evals.csv' file for that. To convert the moves-to-mate evaluations to scores I used the following mapping:
# * '#+3' or higher: +10000 (it doesn't make sense to split longer sequences to different bins as the model is unlikely to distinguish between them, e.g. '#+5' and '#+7')
# * '#+2' : +15000
# * '#+1' : +20000
# * '#+0' : +25000
# * '#-0' : -25000
# * '#-1' : -20000
# * '#-2' : -15000
# * '#-3' or lower: -10000
#
# So the idea is to give the highest score to mate positions, to ensure those moves are preferred by the chess engine.
# In the next cell I load the new dataset and transform it. Then I combine 50k moves-to-mate evaluations and 100k score evaluations into a new dataset.

# %%
# Load the CSV file
df1 = pd.read_csv('data/random_evals.csv')
# Convert the DataFrame to a numpy array
data_random = df1.to_numpy()

# Load the CSV file
df2 = pd.read_csv('data/tactic_evals.csv')
# Convert the DataFrame to a numpy array
data_tactics = df2.to_numpy()

def transform_moves_to_mate_to_score(evaluation):
    """Transform moves to mate evaluation to a score."""
    if evaluation.startswith('#-'):
        moves = int(evaluation[2:])
        if moves > 3:
            return -10000
        else:
            return -5000 * (5 - moves)
    elif evaluation.startswith('#+'):
        moves = int(evaluation[2:])
        if moves > 3:
            return 10000
        else:
            return 5000 * (5 - moves)
    else:
        return float(evaluation)

# take only lines with evaluation starting with '#'
data_tactics = data_tactics[np.char.startswith(data_tactics[:, 1].astype(str), '#')]

# transform the moves-to-mate evaluations to scores
data_tactics[:, 1] = np.array([transform_moves_to_mate_to_score(evaluation) for evaluation in data_tactics[:, 1]])

data_tactics = data_tactics[np.random.choice(data_tactics.shape[0], 50000, replace=False)]

# remove lines with evaluation starting with '#'
data_random = data_random[~np.char.startswith(data_random[:, 1].astype(str), '#')]
data_random = data_random[np.random.choice(data_random.shape[0], 100000, replace=False)]

data_combined = np.concatenate((data_random, data_tactics[:, :2]), axis=0)

# shuffle the combined data
np.random.shuffle(data_combined)

X = data_combined[:, 0]  # Features (FEN strings)
y = data_combined[:, 1].astype(float)  # Labels (evaluations)

# Convert FEN strings to tensors
X_tensors = np.array([board_to_tensor(chess.Board(fen)) for fen in X])
# Reshape the tensors to match the input shape of the model
X_tensors = X_tensors.reshape(X_tensors.shape[0], 8, 8, 17)

# Split the data into training and validation sets
split_index = int(0.8 * len(X_tensors))
X_train = X_tensors[:split_index]
y_train = y[:split_index]
X_val = X_tensors[split_index:]
y_val = y[split_index:]

print(f'X shape: {X_tensors.shape}')
print(f'y shape: {y.shape}')
# Out:
# X shape: (150000, 8, 8, 17)
# y shape: (150000,)

# %% [markdown]
# I will plot the distribution of the new data:

# %%
plt.hist(y, bins=50)
plt.title('Histogram of Scores')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# Now I can train the model on this combined dataset. Interstingly, the Dense layers architecture works much better on the new dataset, than CNN, so I will use 5 Dense layers:

# %%
model = models.Sequential([
    layers.Input(shape=(8, 8, 17)),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='linear')

])

model.compile(optimizer=Adam(learning_rate=0.001),
              loss='mean_squared_error',
              metrics=[tf.keras.metrics.MeanAbsoluteError()])

# Train the model
history = model.fit(X_train, y_train,
                    validation_data=(X_val, y_val),
                    epochs=10,
                    batch_size=32)

# Save the model
model.save('models/model_mixed.keras')
# Out:
# Epoch 1/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - loss: 95468384.0000 - mean_absolute_error: 6024.3311 - val_loss: 61229936.0000 - val_mean_absolute_error: 4536.4150
# Epoch 2/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - loss: 55296984.0000 - mean_absolute_error: 4251.9790 - val_loss: 50278344.0000 - val_mean_absolute_error: 3963.1790
# Epoch 3/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - loss: 41899136.0000 - mean_absolute_error: 3568.3506 - val_loss: 45050856.0000 - val_mean_absolute_error: 3557.8013
# Epoch 4/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - loss: 31494826.0000 - mean_absolute_error: 2962.3274 - val_loss: 43539432.0000 - val_mean_absolute_error: 3334.5200
# Epoch 5/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - loss: 24285210.0000 - mean_absolute_error: 2495.9585 - val_loss: 37915740.0000 - val_mean_absolute_error: 2960.0620
# Epoch 6/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - loss: 20342962.0000 - mean_absolute_error: 2197.4062 - val_loss: 36380476.0000 - val_mean_absolute_error: 2773.2927
# Epoch 7/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - loss: 16705447.0000 - mean_absolute_error: 1943.5042 - val_loss: 34630984.0000 - val_mean_absolute_error: 2653.9795
# Epoch 8/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - loss: 14435786.0000 - mean_absolute_error: 1787.4298 - val_loss: 34435208.0000 - val_mean_absolute_error: 2546.7151
# Epoch 9/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - loss: 12464105.0000 - mean_absolute_error: 1637.6172 - val_loss: 36688720.0000 - val_mean_absolute_error: 2764.6753
# Epoch 10/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - loss: 10976481.0000 - mean_absolute_error: 1538.7050 - val_loss: 34465380.0000 - val_mean_absolute_error: 2506.5410

# %% [markdown]
# The performance metrics are now different, because of the new evaluations. So to have a better idea of model performance, I will plot the sorted predicted vs original evaluations graph for this model:

# %%
plot_predicted_vs_original(X_val, y_val, model)
# Out:
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 751us/step

# %% [markdown]
# The above graph looks suspicious, because even if it looks like my model learned to distinguish between moves-to-mate positions, it looks like the middle range of scores are not predicted well. But there appeared to be an even bigger problem with this model. After trying this model in my chess engine I got the following situation in 3 consequtive games (you probably can figure out the issue):
#
# ![](https://raw.githubusercontent.com/alexber2024/chess/refs/heads/main/images/board4.png)  __  ![](https://raw.githubusercontent.com/alexber2024/chess/refs/heads/main/images/board5.png)  __  ![](https://raw.githubusercontent.com/alexber2024/chess/refs/heads/main/images/board6.png)
#
# The model learned that in order to checkmate, it needs to attack the opponent's king. But it didn't learn that the threat needs to be supported with other pieces (to prevent the loss of the thretening piece). In all 3 games my chess engine attacks the Black king with the Queen, but the Queen is going to be captured in the next move.
#
# The reason to this outcome is in the data. The moves-to-mate positions that I used (the tactics_eval.csv file) were probably taken from winning sequences and my model learned to rank them. However, the model didn't have any "bad" moves to compare to. For example, in '#+1' position there can be 1 "good" move (checkmate), while all other moves lead to a losing position. The model didn't have the data to distinguish between those cases.
#
# To solve that I decided to augment the moves-to-mate data.
#
# #### 4.5 Data augmentation and separate "checkmates" model
#
# I've created a simple script, which goes through move-to-mate positions data, and for each - generates all legal moves in that position and evaluates them using the Stockfish engine, then adds all those new evaluations to the dataset. The idea is to add all existing variations for each position, so the model could learn how different moves change the evaluation, and how "bad" moves look like. Those really bad moves do not exist in the original datasets, but they are very important for training.
#
# Here is the script:

# %%
import chess
import chess.engine

# Load the CSV file
df = pd.read_csv('data/tactic_evals.csv')
# Convert the DataFrame to a numpy array
data = df.to_numpy()

# take only '#' 
data = data[np.char.startswith(data[:, 1].astype(str), '#')]

# The path to the Stockfish engine. You will need to download the Stockfish binary for your platform, if you want to run this code.
# You can download it from https://stockfishchess.org/download/
stockfish_path = "stockfish-macos-m1-apple-silicon"

# Load the Stockfish chess engine
engine = chess.engine.SimpleEngine.popen_uci(stockfish_path)

def mate_score(score):
    return '#+' + str(10000 - score) if score > 0 else '#-' + str(10000 + score)

def augment_moves_to_mate():
    with open("/data/checkmates.csv", "a") as f:
        for row in data:
            fen = row[0]
            score = row[1]
            
            f.write(f"{fen},{score}\n")

            board = chess.Board(fen)
            
            if board.is_checkmate():
                continue

            for move in board.legal_moves:
                board.push(move)
                evaluation = engine.analyse(board, chess.engine.Limit(time=0.05))
                score = evaluation["score"].white().score(mate_score=10000)
                if abs(score) > 9996:  # Check for mate or near-mate
                    f.write(f"{board.fen()},{mate_score(score)}\n")
                else:
                    f.write(f"{board.fen()},{score}\n")
                board.pop()  # Undo the move


# Uncomment  the following line to run
# augment_moves_to_mate()

# %% [markdown]
# Next, I created a new dataset, only using the augmented data:

# %%
# Load the CSV file
df = pd.read_csv('data/checkmates.csv')
# Convert the DataFrame to a numpy array
data_checkmates = df.to_numpy()

# transform the moves-to-mate evaluations to scores
data_checkmates[:, 1] = np.array([transform_moves_to_mate_to_score(evaluation) for evaluation in data_checkmates[:, 1]])

#skip rows with evaluation bigger than 250000
data_checkmates = data_checkmates[data_checkmates[:, 1].astype(float) < 25001]
data_checkmates = data_checkmates[data_checkmates[:, 1].astype(float) > -25001]

data_checkmates = data_checkmates[np.random.choice(data_checkmates.shape[0], 200000, replace=False)]

# shuffle the combined data
np.random.shuffle(data_checkmates)

X = data_checkmates[:, 0]  # Features (FEN strings)
y = data_checkmates[:, 1].astype(float)  # Labels (evaluations)

# Convert FEN strings to tensors
X_tensors = np.array([board_to_tensor(chess.Board(fen)) for fen in X])
# Reshape the tensors to match the input shape of the model
X_tensors = X_tensors.reshape(X_tensors.shape[0], 8, 8, 17)

# Split the data into training and validation sets
split_index = int(0.8 * len(X_tensors))
X_train = X_tensors[:split_index]
y_train = y[:split_index]
X_val = X_tensors[split_index:]
y_val = y[split_index:]

print(f'X shape: {X_tensors.shape}')
print(f'y shape: {y.shape}')
# Out:
# X shape: (200000, 8, 8, 17)
# y shape: (200000,)

# %% [markdown]
# The distribution of scores in the augmented dataset:

# %%
plt.hist(y, bins=50)
plt.title('Histogram of Scores')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# I decided to create a separate model for checkmates (moves-to-mate) evaluations. The Dense layers worked much better for this dataset (I will discuss it in the Results section) Here is the implementation:

# %%
model = models.Sequential([
    layers.Input(shape=(8, 8, 17)),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='linear')

])

model.compile(optimizer=Adam(learning_rate=0.001),
              loss='mean_squared_error',
              metrics=[tf.keras.metrics.MeanAbsoluteError()])

# Train the model
history = model.fit(X_train, y_train,
                    validation_data=(X_val, y_val),
                    epochs=10,
                    batch_size=32)

# Save the model
model.save('models/model_checkmates.keras')
# Out:
# Epoch 1/10
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step - loss: 72023544.0000 - mean_absolute_error: 5344.9272 - val_loss: 53072372.0000 - val_mean_absolute_error: 4802.1069
# Epoch 2/10
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - loss: 47131196.0000 - mean_absolute_error: 4390.4478 - val_loss: 39319328.0000 - val_mean_absolute_error: 3789.6316
# Epoch 3/10
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 35492408.0000 - mean_absolute_error: 3644.2546 - val_loss: 35869696.0000 - val_mean_absolute_error: 3549.6987
# Epoch 4/10
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 29695654.0000 - mean_absolute_error: 3215.3069 - val_loss: 35433924.0000 - val_mean_absolute_error: 3502.3701
# Epoch 5/10
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step - loss: 25220730.0000 - mean_absolute_error: 2858.6067 - val_loss: 31152650.0000 - val_mean_absolute_error: 3208.7988
# Epoch 6/10
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - loss: 21996602.0000 - mean_absolute_error: 2571.5027 - val_loss: 29988468.0000 - val_mean_absolute_error: 2969.0713
# Epoch 7/10
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - loss: 20004870.0000 - mean_absolute_error: 2398.5735 - val_loss: 27596784.0000 - val_mean_absolute_error: 2810.0178
# Epoch 8/10
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - loss: 18165042.0000 - mean_absolute_error: 2221.3145 - val_loss: 26490412.0000 - val_mean_absolute_error: 2694.0703
# Epoch 9/10
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - loss: 16508271.0000 - mean_absolute_error: 2078.2341 - val_loss: 26056472.0000 - val_mean_absolute_error: 2627.3447
# Epoch 10/10
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step - loss: 15428118.0000 - mean_absolute_error: 1993.9502 - val_loss: 25478214.0000 - val_mean_absolute_error: 2655.9207

# %% [markdown]
# And here is the original vs predicted scores plot:

# %%
plot_predicted_vs_original(X_val, y_val, model)
# Out:
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 1s 709us/step

# %% [markdown]
# It looks much better! The model seems to have learned both the moves-to-mate positions and the positions with scores around 0 (which are mostly the augmented positions)

# %% [markdown]
# ##### 4.6 Combining the two models
#
# Now that I had two models, one for regular positions and another for augmented checkmate positions, I decided to combine them, and get a final model for my chess engine. The logic of combining is the following: if checkmate-model score is above 15000 use it as the evaluation, else use evaluation from score-model. And the reasoning behind it is that checkmate-model can recognize a checkmate (or close to mate) positions, which the score-model cannot, but otherwise score-model can make good evaluations.
#
# Here is the implementation of the combined model:

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras import layers, models
import tensorflow as tf

model_scores = load_model('models/model_scores.keras')
model_checkmates = load_model('models/model_checkmates.keras')

# Create a new model that combines the two models in parallel
input_layer = layers.Input(shape=(8, 8, 17))

output_scores = model_scores(input_layer)
output_checkmates = model_checkmates(input_layer)
def select_by_confidence(inputs):
    score, checkmate = inputs
    # If checkmate output is > 15000, trust checkmate model, else trust score model
    threshold = 15000.0
    use_checkmate = tf.abs(checkmate) > threshold
    return tf.where(use_checkmate, checkmate, score)

combined_output = layers.Lambda(select_by_confidence)([output_scores, output_checkmates])

combined_model = models.Model(inputs=input_layer, outputs=combined_output)

combined_model.compile(optimizer='adam',
                       loss='mean_squared_error',
                       metrics=[tf.keras.metrics.MeanAbsoluteError()])

# Save the combined model
combined_model.save('models/model_combined.keras')

# %% [markdown]
# The combined model was finally able to win! I will end this section with a game of my chess engine based on the combined model. My engine wins with a checkmate:
#
# ![](https://raw.githubusercontent.com/alexber2024/chess/refs/heads/main/images/game3.gif)
#
# Here are the details of the final architecture (combined model):

# %%
# model architecture
combined_model.summary()
# Out:
# Model: "functional_200"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_8       │ (None, 8, 8, 17)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_2        │ (None, 1)         │    374,369 │ input_layer_8[0]… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_6        │ (None, 1)         │    730,113 │ input_layer_8[0]… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 1)         │          0 │ sequential_2[0][… │
# │                     │                   │            │ sequential_6[0][… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,104,482 (4.21 MB)
#  Trainable params: 1,104,482 (4.21 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# And here is a diagram of it:
#
# ![](https://raw.githubusercontent.com/alexber2024/chess/refs/heads/main/images/combined_model.jpg)

# %% [markdown]
# ### 5. Results and Discussion
#
# #### 5.1 The chess engine
#
# The results of this project are actually the performance of the model in my chess engine. So before summarizing the results I will share the code of the chess engine. It's a very simple code, based on python-chess, which is using a Deep Learning model to choose the best move given a board state. As I planned, it doesn't use any search algorithm, and simply evaluates all legal moves in a position and return the one with a highest score (or lowest score if plays for Black pieces).
#
# I also added a simple play_game() function, which simulates a game between my chess engine and another engine (Stockfish in the example), and outputs the game moves. Thee list of moves can be feeded in online chess websites to visualize the game (I used chess.com).
#
# Below is the code:

# %%
import chess.engine
import random
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

class SimpleChessEngine:
    def __init__(self, model):
        self.model = model

    def evaluate_position(self, fen):
        board = chess.Board(fen)
        tensor = board_to_tensor(board)
        tensor = np.expand_dims(tensor, axis=0)

        evaluation = self.model.predict(tensor, verbose=0)
        return evaluation[0][0]

    def get_best_move(self, fen, player):
        board = chess.Board(fen)
        best_move = None
        best_evaluation = float('-inf') if player == chess.WHITE else float('inf')

        for move in board.legal_moves:
            board.push(move)
            evaluation = self.evaluate_position(board.fen())

            board.pop()

            if evaluation > best_evaluation:
                best_evaluation = evaluation
                best_move = move

        return best_move
    
def play_game(my_color, my_engine, opponent_engine=None):
    board = chess.Board()
    max_moves = 80
    while not board.is_game_over() and len(board.move_stack) < max_moves:
        if board.turn == my_color:
            move = my_engine.get_best_move(board.fen(), my_color)
        else:
            move = opponent_engine.play(board, chess.engine.Limit(time=0.1)).move

        board.push(move)

    print("Result:", board.result())
    print("Moves history:")
    for move in board.move_stack:
        print(str(move))


# Load the model
model = load_model('models/model_combined.keras', custom_objects={'select_by_confidence': select_by_confidence})
# Create an instance of the SimpleChessEngine with the loaded model
my_engine = SimpleChessEngine(model)

# The path to the Stockfish engine. You will need to download the Stockfish binary for your platform, if you want to run this code.
# You can download it from https://stockfishchess.org/download/
stockfish_path = "stockfish-macos-m1-apple-silicon"

# load Stockfish engine
stockfish_engine = chess.engine.SimpleEngine.popen_uci(stockfish_path)
stockfish_engine.configure({"Skill Level": 1})

play_game(chess.WHITE, my_engine, stockfish_engine)
# Out:
# Result: 1-0
# Moves history:
# g1f3
# e7e6
# h2h3
# a7a6
# d2d3
# a6a5
# c1e3
# b8c6
# b1d2
# g8f6
# a1c1
# a8a7
# e3a7
# e6e5
# b2b4
# a5b4
# c1b1
# f8e7
# d3d4
# g7g5
# d4e5
# e7d6
# e5d6
# b4b3
# d6c7
# c6a5
# c7d8q
# e8d8
# a7b6
# d8e7
# f3g5
# b3c2
# b1c1
# c2d1q
# e1d1
# h7h6
# c1c7
# h8f8
# g5f3
# f8d8
# h3h4
# e7f8
# e2e4
# f6h7
# f3e5
# d7d5
# e4d5
# h6h5
# d5d6
# a5c4
# d2c4
# c8e6
# e5f7
# e6f7
# c4e5
# f8g8
# e5f7
# d8a8
# f7h6
# g8f8
# d1e1
# h7f6
# b6d4
# a8a4
# f1d3
# a4a2
# c7c8
# f8g7
# c8g8
# g7h6
# g8h8
# f6h7
# d6d7
# a2a1
# e1e2
# a1h1
# d3h7
# h1a1
# h7e4

# %% [markdown]
# #### 5.2 Summary of the results
#
# To summarize the results, I've run the game simulator for my engine using different models. Here are the resulting games:
# | Model | Game example | Game Result | Comments |
# |-------|--------------|-------------|----------|
# |Scores Model|![](https://raw.githubusercontent.com/alexber2024/chess/refs/heads/main/images/game1.gif)https://www.chess.com/analysis/game/pgn/5FDNMXMXzn?tab=analysis&move=44| No win after 40 moves |The model learned how to capture pieces, but did't learn how to checkmate|
# |Mixed Model|![](https://raw.githubusercontent.com/alexber2024/chess/refs/heads/main/images/game2.gif)https://www.chess.com/analysis/game/pgn/4ZpL73nPkJ?tab=analysis| Lost on move 29 |The model learned to attack the enemy king, but didn't learn to defend the attacking piece|
# |Combined Model|![](https://raw.githubusercontent.com/alexber2024/chess/refs/heads/main/images/game3.gif)https://www.chess.com/analysis/game/pgn/5bCghDHy42?tab=analysis| Won on move 36 |The combined model knows how to capture pieces and how to checkmate. (And how to do it with style!)|

# %% [markdown]
# I will also share the performance of the partial models:
# |Model|Mean Squarred Error|Original vs Predicted graph|
# |-----|-------------------|---------------------------|
# |Scores Model|277.6|![](https://raw.githubusercontent.com/alexber2024/chess/refs/heads/main/images/original_vs_predicted_scores.png)|
# |Mixed Model|2506.5|![](https://raw.githubusercontent.com/alexber2024/chess/refs/heads/main/images/original_vs_predicted_mixed.png)|
# |Checkmates Model|2655.9|![](https://raw.githubusercontent.com/alexber2024/chess/refs/heads/main/images/original_vs_predicted_checkmates.png)|

# %% [markdown]
# The above figures show that Scores model is quite accurate in its predictions. The mixed and checkmates models are less accurate because they contain both types of evaluations, and also because they were trained on smaller datasets, 150k and 200k.

# %% [markdown]
# #### 5.3 Discussion on architecture. What worked well and what didn't
# Creating a model that could actually win games was a challenging process. I iterated on different architectures for the initial model and tuned the hyperparameters. The choice of CNN proved to work fine, but I wasn't able to take advantage of common regularization techniques. The Dropout and Pooling didn't improve the performance at all. I believe the reason for that is the unique domain of chess rules. Unlike images, where removing a few pixels don't affect the image in general, removing a few pieces from a chess board can drastically affect the position, and turn a winning game into a losing one, or vise versa.
#
# The first model looked very promising, with a low mean error, but after integrating the model into a chess engine and seeing how it plays, I understood that the task is more challenging. To address that, I created another model trained on checkmates positions, and augmented the data to add "bad" positions, so the model could distinguish between good and bad moves. And finally, I combined the two models, and this resulted in a first winning game for my chess engine.

# %% [markdown]
# ### 6. Conclusions
#
# In this project I created a chess engine which is based purely on Deep Learning model. The resulting engine was able to win a game against Stockfish level 1 engine, and I can estimate its playing level to be around 1000 ELO. While this is not a high level, achieving it without relying on search algorithms is a significant result. It shows that Deep Learning model can learn the patterns in different positions and translate them into correct evaluations, which allows the chess engine to play effectively. And indeed, looking at the simulated games, it is clear that the model learned how to attack and capture pieces, how to defend or avoid attacks, and how to checkmate and win the game.
#
# This project also highlighted the imporant aspect of applying Deep Learning model for a real world problem: the performance of the model is not judged only by metrics of the loss function, but also by its ability to solve the real world problem. This requires a different approach and more focus on modeling the real world problem in the right way. In my case, that process included choosing the right encoding, augmenting data and combining 2 different models into an ensemble model.
#
# #### 6.1 Next steps and improvements
#
# A few ideas for improvements:
#
# * I used only 700,000 samples to train the models. And I believe that increasing the data size will significantly improve the performance.
#
# * I also want to augment not only the checkmate positions data, but also regular scores data. So the model will have enough data to distingiush between dab and good moves.
#
# * Another idea is to switch from CNN to Dense layers for the scores model. This will increase the training time, but it should improve the performance, since Dense layers can capture the relations between different pieces in the board directly. This proved to work well for checkmates positions, so it should work well for regular scores also.
#
# * The ability to simulate games and visualize them was very helpful. I want to take it further and create more complex simulations which will run 10s or 100s of games and will produce statistics. I can use it to have a better estimation of an ELO rating of my chess engine.
#
# #### 6.2 Learnings, takeways, and final thoughts
# * One of the most important takeway is that applying a model to a real world problem requires a unique approach and good knowledge of the problem domain.
# * Model performance needs to be adapted to the problem and not only to a loss function metrics
# * The training data quality is very important. The model learns best when it has good and bad examples.
#
# Finally, I can say that this project was a great opportunity to use Deep Learning in practice and combine it with the fascinating topic of chess. In parallel, I explored the ideas behind top chess engines and read some important papers in the field. And I believe the combination of Chess and Deep Learning has huge potential to evolve further and bring new innovations to both fields.

# %% [markdown]
# ### 7. References
#
# * https://chess.com website for chessboard images and games generations.
# * https://www.chessprogramming.org
# * AlphaZero chess engine: https://en.wikipedia.org/wiki/AlphaZero
# * StockFish chess engine: https://en.wikipedia.org/wiki/Stockfish
# * Neural Networks for Chess, by Dominik Klein: https://github.com/asdfjkl/neural_network_chess
